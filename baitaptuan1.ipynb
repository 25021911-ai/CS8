# %%
#W2A1
print("Hello World!")

# %%
#W2A2
print(f"Hello {input("What is your name")}")

# %%
#WA10
a,b,c = input().split()
print(f"Hi {c}, {b} and {a}")

# %%
#W2A16
for i in ["Spring", "Summer", "Autumn", "Winter"]: print(i)

# %%
#W2A17
a = "**"
arr = "*"
for _ in range(3):
    print(arr)
    arr = "".join([a, arr])

# %%
#W2A18
a = '''
### # #  ### ###
 #  #  #  #   #
 #  #   # #   #
 #  #  #  #   #
 #  ##    #   #
'''
print(a)

# %%
#W2A19
for i in ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]: print(i)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
arr = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]; arr.reverse()
def a():
    print(arr.pop())
    if not arr:
        return
    a()
a()
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December
